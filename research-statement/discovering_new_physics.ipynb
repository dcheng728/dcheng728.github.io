# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.uniform(low=0, high=5, size=1000)

# %%
plt.hist(X, density=True)
# Out:
# (array([0.20089259, 0.19084796, 0.18883904, 0.22299078, 0.20089259,
#         0.17678548, 0.18281226, 0.22499971, 0.21495508, 0.20491045]),
#  array([0.02173324, 0.51951167, 1.0172901 , 1.51506853, 2.01284696,
#         2.51062539, 3.00840382, 3.50618225, 4.00396068, 4.50173911,
#         4.99951754]),
#  <BarContainer object of 10 artists>)

# %%
prob_dist = {
    (0,1):0.18,
    (1,2):0.18,
    (2,3):0.28,
    (3,4):0.18,
    (4,5):0.18
}

# %%
0.1/1
